# %%
import numpy as np
import time
from dtaidistance import dtw
from dtaidistance import dtw_visualisation as dtwvis
import random
import math
import warnings
import keras

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])
  except RuntimeError as e:
    print(e)

# %%
def predictEnsemble(ensemble, X):
    X = X.reshape(1, -1)
    predictions = [model.predict(X) for model in ensemble]
    predictions = np.array(predictions)
    predictionsFlipped = predictions.transpose()
    output = []
    for pred in predictionsFlipped:
        mean = pred.mean()
        interval = 1.96 * pred.std()
        lower, upper = mean - interval, mean + interval
        output.append([round(lower), round(mean), round(upper)])
    return output

# %%
def dtwFast(x1, y1, x2, y2, window):
    n, m = len(x1), len(x2)
    w = window
    dtw_matrix = np.zeros((n+1, m+1))
    
    for i in range(n+1):
        for j in range(m+1):
            dtw_matrix[i, j] = np.inf
    dtw_matrix[0, 0] = 0
    
    for i in range(1, n+1):
        ofset = round(i*(m/n))
        for j in range(np.max([1, ofset-w]), np.min([m, ofset+w])+1):
            cost = math.sqrt(((x2[j-1]-x1[i-1])**2)+((y2[j-1]-y1[i-1])**2))#*sample
            last_min = np.min([dtw_matrix[i-1, j], dtw_matrix[i, j-1], dtw_matrix[i-1, j-1]])
            dtw_matrix[i, j] = cost + last_min
    return dtw_matrix    

def get_key(val, my_dict):
    for key, value in my_dict.items():
         if val == value:
             return key

percentErrors = []
percentErrors2 = []
numCorrect = 0
numCorrect2 = 0
numTrials = 0
subTimes1 = []
times1 = []
times2 = []
times3 = []


warnings.filterwarnings('ignore')

length = 60
width = 60
length -= 1
width -= 1
width2 = 11
width2 -= 1

def performDTW(x1, x2, y1, y2, ensemble, scaler):
    n = len(x1)
    m = len(x2)
    if n < 230 or m < 230:
        return 0, 0, 0, [0], 0, 0, 0, 0
    
    x1Samp = [0]*230
    x2Samp = [0]*230
    y1Samp = [0]*230
    y2Samp = [0]*230
    for i in range(len(x1)):
        x1Samp[230*i//len(x1)] = x1[i]
    for i in range(len(x2)):
        x2Samp[230*i//len(x2)] = x2[i]
    for i in range(len(y1)):
        y1Samp[230*i//len(y1)] = y1[i]
    for i in range(len(y2)):
        y2Samp[230*i//len(y2)] = y2[i]
    
    x1SampMax = max(abs(max(x1Samp)), abs(min(x1Samp)))
    x2SampMax = max(abs(max(x2Samp)), abs(min(x2Samp)))
    y1SampMax = max(abs(max(y1Samp)), abs(min(y1Samp)))
    y2SampMax = max(abs(max(y2Samp)), abs(min(y2Samp)))
    for i in range(len(x1Samp)):
        x1Samp[i] /= x1SampMax
    for i in range(len(x2Samp)):
        x2Samp[i] /= x2SampMax
    for i in range(len(y1Samp)):
        y1Samp[i] /= y1SampMax
    for i in range(len(y2Samp)):
        y2Samp[i] /= y2SampMax

    x1, x2, y1, y2 = np.asarray(x1Samp), np.asarray(x2Samp), np.asarray(y1Samp), np.asarray(y2Samp)
    n = len(x1)
    m = len(x2)
    ### ml matrix

    startTime = time.time()

    dtw_matrix = np.zeros((n+1, m+1))
    for i in range(n+1):
        for j in range(m+1):
            dtw_matrix[i, j] = np.inf
    dtw_matrix[0, 0] = 0


    mlinput = []

    mlinput += x1.tolist()[0:length] + y1.tolist()[0:length] + x2.tolist()[0:width] + y2.tolist()[0:width]
    confidence = []
    mlinput = np.array(mlinput)        
    mlinput = mlinput.reshape(1, -1)
    waypoints = []
    waypoints.append(0)
    confidence.append(0.25)
    
    mlStartTime = time.time()
    transformedModelInput = scaler.transform(mlinput)
    
    output = predictEnsemble(ensemble, transformedModelInput)
    for lower, mean, upper in output:
        waypoints.append(mean)
        confidence.append(upper-lower)
    waypoints.append(n)
    confidence.append(0.5)

    mlTime = time.time() - mlStartTime

    for i in range(len(waypoints)):
        waypoints[i] = round(waypoints[i])
    path = [(0, 0)]

    waypointCols = []

    l = []
    for i in range(0, m, m//3):
        l.append(i)
    if len(l) == 3:
        l.append(2)
    if len(l) == 4:
        l.append(m-2)
    l.sort()

    for i in l:
        waypointCols.append(i)

    waypointCols.append(m)

    for i in range(1, len(waypoints)):
        wp0 = waypoints[i]
        curRow, curCol = path[-1][0], path[-1][1]
        wp1 = waypoints[i]
        targetRow = min(max(curRow+1, wp0), n-1)
        targetCol = waypointCols[i]
        if (targetCol - curCol) <= 0:
            while curRow != targetRow:
                path.append((curRow, curCol))
                curRow += 1
        else:
            slope = (targetRow - curRow) / (targetCol - curCol)
            slope = max(0, slope)
            lastRow = curRow
            for i in range(targetCol - curCol):
                path.append((lastRow, (i + curCol)))
                if i == targetCol - curCol - 1:
                    for j in range(lastRow, targetRow):
                        path.append((j, (i + curCol)))
                        lastRow = j
                else:
                    for j in range(lastRow, round(i*slope)+curRow):
                        path.append((j, (i + curCol)))
                        lastRow = j
                    
        best_path = []
        for i in path:
            if i not in best_path:
                best_path.append(i)
    # confidence widths #
    confidenceWidths = []
    widths = []
    for val in confidence:
        confidenceWidths.append(min(60, round((val+1)*12)))
    for i in range(len(confidenceWidths)-1):
        widths.append(confidenceWidths[i])
        slope = (confidenceWidths[i+1]-confidenceWidths[i])/(n//3)
        for j in range(n//3-1):
            widths.append(int(confidenceWidths[i]+slope*j))
    widths.append(confidenceWidths[len(confidenceWidths)-1])
    widths.append(confidenceWidths[len(confidenceWidths)-1])
    subStartTime = time.time()

    for i in range(1, m+1):
        valsInCol = []
        middleVal = 0
        for xVal, yVal in best_path:
            if yVal+1 == i:
                valsInCol.append(yVal)
        if len(valsInCol) != 0:
            middleVal = sum(valsInCol) // len(valsInCol)
        width2 = widths[i-1]
        if len(valsInCol) >= width2:
            width2 = len(valsInCol) + 1

        if middleVal-(width2//2) < 0:
            xi = 1
            xf = min(n, xi+width2)
        else:
            xf = min(n, middleVal+(width2//2+1))
            xi = xf-width2
        if i == 1:
            xi = 1
            xf = min(n, xi+width2)
        elif i == m:
            xf = n
            xi = xf-width2
        for j in range(xi, xf+1):
            if dtw_matrix[j, i] == np.inf:
                cost = math.sqrt(((x2[i-1]-x1[j-1])**2)+((y2[i-1]-y1[j-1])**2))
                last_min = np.min([dtw_matrix[j-1, i], dtw_matrix[j, i-1], dtw_matrix[j-1, i-1]])
                dtw_matrix[j, i] = cost + last_min

    dist1 = dtw_matrix[len(dtw_matrix)-1][len(dtw_matrix[0])-1]
    endTime = time.time()
    elapsedTime1 = endTime - startTime
    subElaspedTime1 = endTime - subStartTime
    best_path1 = dtw.best_path(dtw_matrix)
    #dtwvis.plot_warpingpaths(x1, x2, dtw_matrix, best_path1)
    ### full matrix
    startTime = time.time()
    dtw_matrix2 = np.zeros((n+1, m+1))
    for i in range(n+1):
        for j in range(m+1):
            dtw_matrix2[i, j] = np.inf
    dtw_matrix2[0, 0] = 0

    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = math.sqrt(((x2[j-1]-x1[i-1])**2)+((y2[j-1]-y1[i-1])**2))
            last_min = np.min([dtw_matrix2[i-1, j], dtw_matrix2[i, j-1], dtw_matrix2[i-1, j-1]])
            dtw_matrix2[i, j] = cost + last_min
    
    endTime = time.time()
    elapsedTime2 = endTime - startTime

    dist2 = dtw_matrix2[len(dtw_matrix2)-1][len(dtw_matrix2[0])-1]
    best_path2 = dtw.best_path(dtw_matrix2)
    #dtwvis.plot_warpingpaths(x1, x2, dtw_matrix2, best_path2)

    # fast matrix
    startTime = time.time()
    dtw_matrix3 = dtwFast(x1, y1, x2, y2, 14)
    endTime = time.time()
    elapsedTime3 = endTime - startTime
    dist3 = dtw_matrix3[len(dtw_matrix3)-1][len(dtw_matrix3[0])-1]
    best_path3 = dtw.best_path(dtw_matrix3)
    #dtwvis.plot_warpingpaths(x1, x2, dtw_matrix3, best_path3)
    #plt.show()
    return dist1, dist2, dist3, best_path1, x1, x2, y1, y2

# %%
character = "signature"

# %%
import csv
xTrain = []
yTrain = []
with open(f'{character}Data.csv', newline='') as csvfile: #signatureData, letterAData.csv
    csv_reader = csv.reader(csvfile, delimiter=',')
    counter = 0
    for line in csv_reader:
        for i in range(len(line)):
            line[i] = float(line[i])
        if counter % 2 == 0:
            xTrain.append(line) 
        else:
            yTrain.append(line)
        counter += 1

# %%
# application signature iPad Version

from math import pi
import numpy as np
from ipycanvas import MultiCanvas
import copy
import matplotlib.pyplot as plt
from pickle import load
from keras.src.legacy.saving import legacy_h5_format

# ml full fast
canvas  = MultiCanvas(2, width=1600, height=1200, layout=dict(width="100%"))

signatureEnsemble = []
for i in range(5):
    # signatureEnsemble.append(keras.models.load_model(f'{character}_{i}.h5'))
    signatureEnsemble.append(legacy_h5_format.load_model_from_hdf5(f'{character}_{i}.h5', custom_objects={'mae': 'mae'}))

signatureScaler = load(open(f'scaler_{character}.pkl', 'rb'))

from ipywidgets import Output

drawOn = False
letterX = []
letterY = []
canvas[0]
xPos = 0
yPos = 0

letterR_X = xTrain[15]
letterR_Y = yTrain[15]
for i in range(len(letterR_X)):
    canvas[0].fill_arc(letterR_X[i]+100, -1*(letterR_Y[i])+500, 5, 0, 180)
canvas[0].fill_rect(50, 1000, 1500, 5)

canvas[1]  
out = Output()
@out.capture()
def handle_mouse_move(x, y):
    global drawOn
    global letterX
    global letterY
    global xPos
    global yPos
    xPos = x
    yPos = y
    if drawOn:
        canvas[1].fill_arc(x, y, 5, 0, 180)
        letterX.append(x)
        letterY.append(-1*(y))

canvas.on_mouse_move(handle_mouse_move)

@out.capture()
def on_keyboard_event(key, shift_key, ctrl_key, meta_key):
    global drawOn
    global letterX
    global letterY
    global xPos
    global yPos
    global letterR_X
    global letterR_Y
    if key == " ":
        drawOn = not drawOn
        if drawOn:
            return 0
        startX = letterX[0]
        startY = letterY[0]
        for i in range(len(letterX)):
            letterX[i] -= startX
            letterY[i] -= startY
        dist1, dist2, dist3, best_path, x1, x2, y1, y2 = performDTW(letterR_X, letterX, letterR_Y, letterY, signatureEnsemble, signatureScaler)
        if dist1 == 0:
            print("need more points")
        else:
            avgdist1 = 0
            avgdist2 = 0
            avgdist3 = 0
            passes = 10
            
            for i in range(passes):
                sample = random.randint(0, len(xTrain)-1)
                dist1, dist2, dist3, valbest_path, valx1, valx2, valy1, valy2 = performDTW(xTrain[sample], letterX, yTrain[sample], letterY, signatureEnsemble, signatureScaler)
                percentError = (abs(dist1 - dist2) / dist2) * 100
                percentErrors.append(percentError)

                percentError2 = (abs(dist3 - dist2) / dist2) * 100
                percentErrors2.append(percentError2)

                avgdist1 += dist1
                avgdist2 += dist2
                avgdist3 += dist3
            avgdist1 /= passes
            avgdist2 /= passes
            avgdist3 /= passes
            plt.plot(x1, y1, 'o', color='blue')
            plt.plot(x2, y2, 'o', color='red')
            counter = 0
            for a, b in best_path:
                if counter % 1 == 0:
                    point1 = [x1[a], y1[a]]
                    point2 = [x2[b], y2[b]]
                    x_values = [point1[0], point2[0]]
                    y_values = [point1[1], point2[1]]
                    plt.plot(x_values, y_values, 'g', linestyle="--") 
                counter += 1
            plt.show()

            if avgdist1 < 25:
                print("correct")
            elif 25 < avgdist1 < 32:
                print("maybe correct")
            else:
                print("incorrect")
            print("MLDTW:", avgdist1, "Full DTW:", avgdist2, "FastDTW:", avgdist3)
        letterX = []
        letterY = []
        canvas[1].clear()


@out.capture()
def handle_mouse_down(x, y):
    global drawOn
    global letterX
    global letterY
    
canvas.on_key_down(on_keyboard_event)
canvas.on_mouse_down(handle_mouse_down)
display(out)

display(canvas)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Output()
# MultiCanvas(height=1200, layout=Layout(width='100%'), width=1600)

# %%
# application signature

from math import pi
import numpy as np
from ipycanvas import MultiCanvas
import copy
import matplotlib.pyplot as plt
from pickle import load
from keras.src.legacy.saving import legacy_h5_format

# ml full fast
canvas  = MultiCanvas(2, width=1600, height=1200, layout=dict(width="100%"))

signatureEnsemble = []
for i in range(5):
    # signatureEnsemble.append(keras.models.load_model(f'{character}_{i}.h5'))
    signatureEnsemble.append(legacy_h5_format.load_model_from_hdf5(f'{character}_{i}.h5', custom_objects={'mae': 'mae'}))

signatureScaler = load(open(f'scaler_{character}.pkl', 'rb'))

from ipywidgets import Output

drawOn = False
letterX = []
letterY = []
canvas[0]
xPos = 0
yPos = 0

letterR_X = xTrain[15]
letterR_Y = yTrain[15]

for i in range(len(letterR_X)):
    canvas[0].fill_arc(letterR_X[i]+100, -1*(letterR_Y[i])+500, 5, 0, 180)
canvas[0].fill_rect(50, 1000, 1500, 5)

canvas[1]  
out = Output()
@out.capture()
def handle_mouse_move(x, y):
    global drawOn
    global letterX
    global letterY
    global xPos
    global yPos
    xPos = x
    yPos = y
    if drawOn:
        canvas[1].fill_arc(x, y, 5, 0, 180)
        letterX.append(x)
        letterY.append(-1*(y))

canvas.on_mouse_move(handle_mouse_move)

@out.capture()
def on_keyboard_event(key, shift_key, ctrl_key, meta_key):
    global drawOn
    global letterX
    global letterY
    global xPos
    global yPos
    global letterR_X
    global letterR_Y
    if key == " ":
        startX = letterX[0]
        startY = letterY[0]
        for i in range(len(letterX)):
            letterX[i] -= startX
            letterY[i] -= startY
        dist1, dist2, dist3, best_path, x1, x2, y1, y2 = performDTW(letterR_X, letterX, letterR_Y, letterY, signatureEnsemble, signatureScaler)
        if dist1 == 0:
            print("need more points")
        else:
            avgdist1 = 0
            avgdist2 = 0
            avgdist3 = 0
            passes = 10
            
            for i in range(passes):
                sample = random.randint(0, len(xTrain)-1)
                dist1, dist2, dist3, valbest_path, valx1, valx2, valy1, valy2 = performDTW(xTrain[sample], letterX, yTrain[sample], letterY, signatureEnsemble, signatureScaler)
                percentError = (abs(dist1 - dist2) / dist2) * 100
                percentErrors.append(percentError)

                percentError2 = (abs(dist3 - dist2) / dist2) * 100
                percentErrors2.append(percentError2)

                avgdist1 += dist1
                avgdist2 += dist2
                avgdist3 += dist3
            avgdist1 /= passes
            avgdist2 /= passes
            avgdist3 /= passes
            plt.plot(x1, y1, 'o', color='blue')
            plt.plot(x2, y2, 'o', color='red')
            counter = 0
            for a, b in best_path:
                if counter % 1 == 0:
                    point1 = [x1[a], y1[a]]
                    point2 = [x2[b], y2[b]]
                    x_values = [point1[0], point2[0]]
                    y_values = [point1[1], point2[1]]
                    plt.plot(x_values, y_values, 'g', linestyle="--") 
                counter += 1
            plt.show()

            if avgdist1 < 25:
                print("correct")
            elif 25 < avgdist1 < 32:
                print("maybe correct")
            else:
                print("incorrect")
            print("MLDTW:", avgdist1, "Full DTW:", avgdist2, "FastDTW:", avgdist3)
        letterX = []
        letterY = []
        canvas[1].clear()
        drawOn = False


@out.capture()
def handle_mouse_down(x, y):
    global drawOn
    global letterX
    global letterY
    drawOn = not drawOn
    
canvas.on_key_down(on_keyboard_event)
canvas.on_mouse_down(handle_mouse_down)
display(out)

display(canvas)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Output()
# MultiCanvas(height=1200, layout=Layout(width='100%'), width=1600)

# %%
# set base signal

letterR_X = []
letterR_Y = []

from math import pi
import numpy as np
from ipycanvas import MultiCanvas
import copy
import matplotlib.pyplot as plt

# ml full fast
canvas  = MultiCanvas(2, width=1600, height=1200, layout=dict(width="100%"))

from ipywidgets import Output

drawOn = False
letterX = []
letterY = []
startX = 0
startY = 0
canvas[0]
for i in range(len(xTrain[10])):
    canvas[0].fill_arc(xTrain[10][i], -1*(yTrain[10][i])-500, 5, 0, 180)

canvas[1]  
out = Output()
@out.capture()
def handle_mouse_move(x, y):
    global drawOn
    global letterX
    global letterY
    global startX
    global startY
    if drawOn:
        canvas[1].fill_arc(x, y, 5, 0, 180)
        letterX.append(x-startX)
        letterY.append(-1*(y-startY))

canvas.on_mouse_move(handle_mouse_move)

@out.capture()
def handle_mouse_down(x, y):
    global drawOn
    global letterX
    global letterY
    global startX
    global startY
    global letterR_X
    global letterR_Y
    if drawOn:
        letterR_X = letterX
        letterR_Y = letterY

        dist1, dist2, dist3, best_path, x1, x2, y1, y2 = performDTW(xTrain[10], letterX, yTrain[10], letterY)
        plt.plot(x1, y1, 'o', color='blue')
        plt.plot(x2, y2, 'o', color='red')
        counter = 0
        for a, b in best_path:
            if counter % 1 == 0:
                point1 = [x1[a], y1[a]]
                point2 = [x2[b], y2[b]]
                x_values = [point1[0], point2[0]]
                y_values = [point1[1], point2[1]]
                plt.plot(x_values, y_values, 'g', linestyle="--") 
            counter += 1
        plt.show()

        if dist1 < 15000:
            print("r")
        else:
            print("not r")
        print("MLDTW:", dist1, "Full DTW:", dist2, "FastDTW:", dist3)
        letterX = []
        letterY = []
        canvas[1].clear()
    else:
         startX = x
         startY = y
    drawOn = not drawOn
    

canvas.on_mouse_down(handle_mouse_down)
display(out)

display(canvas)
# Out:
# Output()
# MultiCanvas(height=1200, layout=Layout(width='100%'), width=1600)

# %%
# collect data

import csv
from math import pi
import numpy as np
from ipycanvas import MultiCanvas
import copy
import matplotlib.pyplot as plt

# ml full fast
canvas  = MultiCanvas(2, width=1600, height=1200, layout=dict(width="100%"))

from ipywidgets import Output

drawOn = False
letterX = []
letterY = []
canvas[0]
xPos = 0
yPos = 0

canvas[1]  
out = Output()
@out.capture()
def handle_mouse_move(x, y):
    global drawOn
    global letterX
    global letterY
    global xPos
    global yPos
    xPos = x
    yPos = y
    if drawOn:
        canvas[1].fill_arc(x, y, 5, 0, 180)
        letterX.append(x)
        letterY.append(-1*(y))

canvas.on_mouse_move(handle_mouse_move)

@out.capture()
def on_keyboard_event(key, shift_key, ctrl_key, meta_key):
    global drawOn
    global letterX
    global letterY
    global xPos
    global yPos
    if key == " ":
        startX = letterX[0]
        startY = letterY[0]
        for i in range(len(letterX)):
            letterX[i] -= startX
            letterY[i] -= startY
        file = open(f'letterAData.csv','a', newline='')
        with file:
            writer = csv.writer(file)
            writer.writerow(letterX)
            writer.writerow(letterY)
        letterX = []
        letterY = []
        canvas[1].clear()
        drawOn = False

        print('Keyboard event:', key, shift_key, ctrl_key, meta_key)

@out.capture()
def handle_mouse_down(x, y):
    global drawOn
    global letterX
    global letterY
    drawOn = not drawOn
    
canvas.on_key_down(on_keyboard_event)
canvas.on_mouse_down(handle_mouse_down)
display(out)

display(canvas)
# Out:
# Output()
# MultiCanvas(height=1200, layout=Layout(width='100%'), width=1600)

# %%
from sklearn.model_selection import train_test_split

import math
from dtaidistance import dtw
from dtaidistance import dtw_visualisation as dtwvis
import numpy as np
import csv
import os

def myround(x, base):
    return base * round(x/base)

label = ""
#character = "signature"

xTrain, xTest, yTrain, yTest = train_test_split(xTrain, yTrain, test_size=0.1,  random_state=1)

length = 60 #10 for a's
width = 60 #10 for a's
length -= 1
width -= 1

file = f'handwriting_{character}_StartWave.csv'
if(os.path.exists(file) and os.path.isfile(file)):
    os.remove(file)

header = ""
# for i in range(length):
#     for j in range(width):
#         header += f"col {i}: {j}, "
for i in range(length):
    header += f"x1_{i}, "
for i in range(length):
    header += f"y1_{i}, "
for j in range(width):
    header += f"x2_{j}, "
for j in range(width):
    header += f"y2_{j}, "
for i in range(4):
    header += f"waypoints {i}, "

header = header.split(", ")
header.pop()
file = open(f'handwriting_{character}_StartWave.csv','w', newline='')
with file:
    writer = csv.writer(file)
    writer.writerow(header)

for n1 in range(len(xTrain)):
    for n2 in range(len(xTrain)):
        if n1 == n2:
            continue
        
        x1, x2, y1, y2 = xTrain[n1], xTrain[n2], yTrain[n1], yTrain[n2]
        minLength = 230 #35 for a's, 230 for sig
        n = len(x1)
        m = len(x2)
        if n < minLength or m < minLength:
            continue
        
        x1Samp = [0]*minLength
        x2Samp = [0]*minLength
        y1Samp = [0]*minLength
        y2Samp = [0]*minLength
        for i in range(len(x1)):
            x1Samp[minLength*i//len(x1)] = x1[i]
        for i in range(len(x2)):
            x2Samp[minLength*i//len(x2)] = x2[i]
        for i in range(len(y1)):
            y1Samp[minLength*i//len(y1)] = y1[i]
        for i in range(len(y2)):
            y2Samp[minLength*i//len(y2)] = y2[i]

        x1SampMax = max(abs(max(x1Samp)), abs(min(x1Samp)))
        x2SampMax = max(abs(max(x2Samp)), abs(min(x2Samp)))
        y1SampMax = max(abs(max(y1Samp)), abs(min(y1Samp)))
        y2SampMax = max(abs(max(y2Samp)), abs(min(y2Samp)))
        for i in range(len(x1Samp)):
            x1Samp[i] /= x1SampMax
        for i in range(len(x2Samp)):
            x2Samp[i] /= x2SampMax
        for i in range(len(y1Samp)):
            y1Samp[i] /= y1SampMax
        for i in range(len(y2Samp)):
            y2Samp[i] /= y2SampMax

        x1, x2, y1, y2 = np.asarray(x1Samp), np.asarray(x2Samp), np.asarray(y1Samp), np.asarray(y2Samp)
        n = len(x1)
        m = len(x2)
        dtw_matrix = np.zeros((n+1, m+1))
        for i in range(n+1):
            for j in range(m+1):
                dtw_matrix[i, j] = np.inf
        dtw_matrix[0, 0] = 0
        for i in range(1, n+1):
            for j in range(1, m+1):
                cost = math.sqrt(((x2[j-1]-x1[i-1])**2)+((y2[j-1]-y1[i-1])**2))
                last_min = np.min([dtw_matrix[i-1, j], dtw_matrix[i, j-1], dtw_matrix[i-1, j-1]])
                dtw_matrix[i, j] = cost + last_min
        dist = dtw_matrix[len(dtw_matrix)-1][len(dtw_matrix[0])-1]
        best_path = dtw.best_path(dtw_matrix)
        
        dtw_matrix = np.zeros((n+1, m+1))
        for i in range(n+1):
            for j in range(m+1):
                dtw_matrix[i, j] = np.inf
        dtw_matrix[0, 0] = 0

        line = []

        line += x1.tolist()[0:length] + y1.tolist()[0:length] + x2.tolist()[0:width] + y2.tolist()[0:width]

        waypoints = []
        l = []
        for i in range(0, m, m//3):
            l.append(i)
        if len(l) == 3:
            l.append(2)
        if len(l) == 4:
            l.append(m-2)
        l.sort()
        for i in l:
            vals = []
            for row, col in best_path:
                if col == i:
                    vals.append(row)
            waypoints.append((sum(vals)//len(vals), i))
        waypoints.pop(0)
        for wprow, wpcol in waypoints:
            line.append(wprow)
        if len(waypoints) == 4:
            file = open(f'handwriting_{character}_StartWave.csv','a', newline='')
            with file:
                writer = csv.writer(file)
                writer.writerow(line)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow import keras 
import warnings
from pickle import dump


data = pd.read_csv(f'handwriting_{character}_StartWave.csv')

encoder = LabelEncoder()
y = np.array(data.iloc[:, -4:])
for i in range(4):
    data=data.drop([f"waypoints {i}"],axis=1)
#for i in range(30,199):
#    data=data.drop([f"x1_{i}"],axis=1)
#for i in range(30,199):
 #   data=data.drop([f"x2_{i}"],axis=1)
scaler = StandardScaler()
array = np.array(data.iloc[:])
#array = array.astype(int)
scaler.fit(array)
X = scaler.transform(np.array(data.iloc[:]))
dump(scaler, open(f'scaler_{character}.pkl', 'wb'))
X_train_ML, X_test_ML, y_train_ML, y_test_ML = train_test_split(X, y, test_size=0.1,  random_state=1)

# %%
from sklearn.metrics import mean_absolute_error

from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

def fitModel(X_train, y_train):
    n_inputs, n_outputs = X_train.shape[1], y_train.shape[1]
    early_stopping = EarlyStopping(monitor='loss', patience=40)
    model = models.Sequential()
    model.add(layers.Dense(200,  activation='relu', kernel_initializer='he_uniform', input_shape =(n_inputs,)))
    model.add(layers.Dense(n_outputs, kernel_initializer='he_uniform'))
    model.compile(optimizer='adam', loss='mae', metrics =['accuracy'])
    model.fit(X_train, y_train, epochs=500, callbacks=[early_stopping])
    return model

def fitEnsemble(n_members, X_train, X_test, y_train, y_test):
    ensemble = list()
    for i in range(n_members):
        model = fitModel(X_train, y_train)
        yhat = model.predict(X_test, verbose=0)
        mae = mean_absolute_error(y_test, yhat)
        print('>%d, MAE: %.3f' % (i+1, mae))
        ensemble.append(model)
        model.save(f'{character}_{i}.h5')
    return ensemble

X_train_ML, X_test_ML, y_train_ML, y_test_ML = train_test_split(X, y, test_size=0.1,  random_state=1)
ensemble = fitEnsemble(5, X_train_ML, X_test_ML, y_train_ML, y_test_ML)
# Out:
# Epoch 1/500
# 9/9 [==============================] - 0s 7ms/step - loss: 170.2754 - accuracy: 0.5091
# Epoch 2/500
# 9/9 [==============================] - 0s 5ms/step - loss: 167.8727 - accuracy: 0.4836
# Epoch 3/500
# 2022-04-27 16:13:49.080263: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 9/9 [==============================] - 0s 5ms/step - loss: 165.1169 - accuracy: 0.4473
# Epoch 4/500
# 9/9 [==============================] - 0s 5ms/step - loss: 161.6414 - accuracy: 0.4691
# Epoch 5/500
# 9/9 [==============================] - 0s 5ms/step - loss: 157.1598 - accuracy: 0.4982
# Epoch 6/500
# 9/9 [==============================] - 0s 5ms/step - loss: 151.4306 - accuracy: 0.5018
# Epoch 7/500
# 9/9 [==============================] - 0s 5ms/step - loss: 144.2603 - accuracy: 0.5273
# Epoch 8/500
# 9/9 [==============================] - 0s 5ms/step - loss: 135.2248 - accuracy: 0.5491
# Epoch 9/500
# 9/9 [==============================] - 0s 5ms/step - loss: 124.5601 - accuracy: 0.5564
# Epoch 10/500
# 9/9 [==============================] - 0s 5ms/step - loss: 112.9064 - accuracy: 0.5891
# Epoch 11/500
# 9/9 [==============================] - 0s 5ms/step - loss: 101.4674 - accuracy: 0.6364
# Epoch 12/500
# 9/9 [==============================] - 0s 5ms/step - loss: 89.1718 - accuracy: 0.6473
# Epoch 13/500
# 9/9 [==============================] - 0s 5ms/step - loss: 76.0673 - accuracy: 0.6727
# Epoch 14/500
# 9/9 [==============================] - 0s 6ms/step - loss: 63.5196 - accuracy: 0.7491
# Epoch 15/500
# 9/9 [==============================] - 0s 5ms/step - loss: 52.2565 - accuracy: 0.8509
# Epoch 16/500
# 9/9 [==============================] - 0s 5ms/step - loss: 43.2578 - accuracy: 0.9418
# Epoch 17/500
# 9/9 [==============================] - 0s 5ms/step - loss: 36.1851 - accuracy: 0.9491
# Epoch 18/500
# 9/9 [==============================] - 0s 5ms/step - loss: 30.7916 - accuracy: 0.9091
# Epoch 19/500
# 9/9 [==============================] - 0s 5ms/step - loss: 25.7710 - accuracy: 0.8182
# Epoch 20/500
# 9/9 [==============================] - 0s 6ms/step - loss: 21.4457 - accuracy: 0.7309
# Epoch 21/500
# 9/9 [==============================] - 0s 6ms/step - loss: 18.0261 - accuracy: 0.5855
# Epoch 22/500
# 9/9 [==============================] - 0s 7ms/step - loss: 15.4996 - accuracy: 0.6036
# Epoch 23/500
# 9/9 [==============================] - 0s 5ms/step - loss: 13.5191 - accuracy: 0.5491
# Epoch 24/500
# 9/9 [==============================] - 0s 5ms/step - loss: 12.0165 - accuracy: 0.3964
# Epoch 25/500
# 9/9 [==============================] - 0s 5ms/step - loss: 10.8690 - accuracy: 0.3236
# Epoch 26/500
# 9/9 [==============================] - 0s 5ms/step - loss: 9.7996 - accuracy: 0.4509
# Epoch 27/500
# 9/9 [==============================] - 0s 11ms/step - loss: 8.9465 - accuracy: 0.4327
# Epoch 28/500
# 9/9 [==============================] - 0s 5ms/step - loss: 8.1729 - accuracy: 0.4000
# Epoch 29/500
# 9/9 [==============================] - 0s 6ms/step - loss: 7.5676 - accuracy: 0.4436
# Epoch 30/500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.9274 - accuracy: 0.4909
# Epoch 31/500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.3880 - accuracy: 0.3782
# Epoch 32/500
# 9/9 [==============================] - 0s 5ms/step - loss: 5.8567 - accuracy: 0.3818
# Epoch 33/500
# 9/9 [==============================] - 0s 6ms/step - loss: 5.3207 - accuracy: 0.5055
# Epoch 34/500
# 9/9 [==============================] - 0s 5ms/step - loss: 4.8182 - accuracy: 0.4836
# Epoch 35/500
# 9/9 [==============================] - 0s 5ms/step - loss: 4.3574 - accuracy: 0.4255
# Epoch 36/500
# 9/9 [==============================] - 0s 5ms/step - loss: 4.0055 - accuracy: 0.4473
# Epoch 37/500
# 9/9 [==============================] - 0s 6ms/step - loss: 3.5813 - accuracy: 0.4182
# Epoch 38/500
# 9/9 [==============================] - 0s 6ms/step - loss: 3.2699 - accuracy: 0.4364
# Epoch 39/500
# 9/9 [==============================] - 0s 6ms/step - loss: 2.9390 - accuracy: 0.4582
# Epoch 40/500
# 9/9 [==============================] - 0s 5ms/step - loss: 2.6509 - accuracy: 0.4691
# Epoch 41/500
# 9/9 [==============================] - 0s 5ms/step - loss: 2.4496 - accuracy: 0.5236
# Epoch 42/500
# 9/9 [==============================] - 0s 5ms/step - loss: 2.3232 - accuracy: 0.5055
# Epoch 43/500
# 9/9 [==============================] - 0s 5ms/step - loss: 2.2369 - accuracy: 0.6582
# Epoch 44/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.9575 - accuracy: 0.5709
# Epoch 45/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.8420 - accuracy: 0.4255
# Epoch 46/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.7624 - accuracy: 0.6182
# Epoch 47/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.7000 - accuracy: 0.3927
# Epoch 48/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.6820 - accuracy: 0.5273
# Epoch 49/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.5514 - accuracy: 0.5018
# Epoch 50/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.4025 - accuracy: 0.5636
# Epoch 51/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.3788 - accuracy: 0.5091
# Epoch 52/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.4072 - accuracy: 0.5455
# Epoch 53/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.3689 - accuracy: 0.4182
# Epoch 54/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.2285 - accuracy: 0.6073
# Epoch 55/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.1782 - accuracy: 0.3673
# Epoch 56/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.1561 - accuracy: 0.5382
# Epoch 57/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.1602 - accuracy: 0.6218
# Epoch 58/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0595 - accuracy: 0.4145
# Epoch 59/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0784 - accuracy: 0.5164
# Epoch 60/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0522 - accuracy: 0.4727
# Epoch 61/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0024 - accuracy: 0.5055
# Epoch 62/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0531 - accuracy: 0.6000
# Epoch 63/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0482 - accuracy: 0.3927
# Epoch 64/500
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0462 - accuracy: 0.5855
# Epoch 65/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0877 - accuracy: 0.4436
# Epoch 66/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0742 - accuracy: 0.4109
# Epoch 67/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0557 - accuracy: 0.5091
# Epoch 68/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9290 - accuracy: 0.5055
# Epoch 69/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8806 - accuracy: 0.4982
# Epoch 70/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7965 - accuracy: 0.5636
# Epoch 71/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8576 - accuracy: 0.5164
# Epoch 72/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8661 - accuracy: 0.5127
# Epoch 73/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8846 - accuracy: 0.4727
# Epoch 74/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8644 - accuracy: 0.6545
# Epoch 75/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8484 - accuracy: 0.4436
# Epoch 76/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8526 - accuracy: 0.5891
# Epoch 77/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8616 - accuracy: 0.5745
# Epoch 78/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7839 - accuracy: 0.3964
# Epoch 79/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8100 - accuracy: 0.5055
# Epoch 80/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8354 - accuracy: 0.5673
# Epoch 81/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7706 - accuracy: 0.4582
# Epoch 82/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7544 - accuracy: 0.5673
# Epoch 83/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7221 - accuracy: 0.5091
# Epoch 84/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7339 - accuracy: 0.5491
# Epoch 85/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7831 - accuracy: 0.4691
# Epoch 86/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7707 - accuracy: 0.4909
# Epoch 87/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7740 - accuracy: 0.6218
# Epoch 88/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8274 - accuracy: 0.4255
# Epoch 89/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7790 - accuracy: 0.4691
# Epoch 90/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7282 - accuracy: 0.5636
# Epoch 91/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7111 - accuracy: 0.4582
# Epoch 92/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6947 - accuracy: 0.3709
# Epoch 93/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7099 - accuracy: 0.5018
# Epoch 94/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6929 - accuracy: 0.5236
# Epoch 95/500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.7170 - accuracy: 0.5455
# Epoch 96/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6766 - accuracy: 0.4364
# Epoch 97/500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.6655 - accuracy: 0.4727
# Epoch 98/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6656 - accuracy: 0.4436
# Epoch 99/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6675 - accuracy: 0.5855
# Epoch 100/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6394 - accuracy: 0.4291
# Epoch 101/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6816 - accuracy: 0.4836
# Epoch 102/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6517 - accuracy: 0.5964
# Epoch 103/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6771 - accuracy: 0.3818
# Epoch 104/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6629 - accuracy: 0.4655
# Epoch 105/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7857 - accuracy: 0.4909
# Epoch 106/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7350 - accuracy: 0.4945
# Epoch 107/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6917 - accuracy: 0.4582
# Epoch 108/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7390 - accuracy: 0.4364
# Epoch 109/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6116 - accuracy: 0.5382
# Epoch 110/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6385 - accuracy: 0.5091
# Epoch 111/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6270 - accuracy: 0.6073
# Epoch 112/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7024 - accuracy: 0.4582
# Epoch 113/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6802 - accuracy: 0.4982
# Epoch 114/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6355 - accuracy: 0.5491
# Epoch 115/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6405 - accuracy: 0.4073
# Epoch 116/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5852 - accuracy: 0.5055
# Epoch 117/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5773 - accuracy: 0.5200
# Epoch 118/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6061 - accuracy: 0.5855
# Epoch 119/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5729 - accuracy: 0.4545
# Epoch 120/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5015 - accuracy: 0.3891
# Epoch 121/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5178 - accuracy: 0.4909
# Epoch 122/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6156 - accuracy: 0.4873
# Epoch 123/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6228 - accuracy: 0.4800
# Epoch 124/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6267 - accuracy: 0.5055
# Epoch 125/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6222 - accuracy: 0.5709
# Epoch 126/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5941 - accuracy: 0.3782
# Epoch 127/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6030 - accuracy: 0.5273
# Epoch 128/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6269 - accuracy: 0.5600
# Epoch 129/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5821 - accuracy: 0.5018
# Epoch 130/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5147 - accuracy: 0.4255
# Epoch 131/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5647 - accuracy: 0.3927
# Epoch 132/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5964 - accuracy: 0.5673
# Epoch 133/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5709 - accuracy: 0.4291
# Epoch 134/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6010 - accuracy: 0.4655
# Epoch 135/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5770 - accuracy: 0.4182
# Epoch 136/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5725 - accuracy: 0.6036
# Epoch 137/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5574 - accuracy: 0.5091
# Epoch 138/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5542 - accuracy: 0.5091
# Epoch 139/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5090 - accuracy: 0.5745
# Epoch 140/500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5205 - accuracy: 0.4436
# Epoch 141/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4871 - accuracy: 0.3891
# Epoch 142/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5226 - accuracy: 0.4327
# Epoch 143/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5289 - accuracy: 0.6218
# Epoch 144/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5220 - accuracy: 0.5527
# Epoch 145/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5543 - accuracy: 0.4145
# Epoch 146/500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.6224 - accuracy: 0.4873
# Epoch 147/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4845 - accuracy: 0.5236
# Epoch 148/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4754 - accuracy: 0.5018
# Epoch 149/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5165 - accuracy: 0.5855
# Epoch 150/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4943 - accuracy: 0.4000
# Epoch 151/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5408 - accuracy: 0.5164
# Epoch 152/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5179 - accuracy: 0.4873
# Epoch 153/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5484 - accuracy: 0.3418
# Epoch 154/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5131 - accuracy: 0.5345
# Epoch 155/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4818 - accuracy: 0.4000
# Epoch 156/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4931 - accuracy: 0.5418
# Epoch 157/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4954 - accuracy: 0.5564
# Epoch 158/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4799 - accuracy: 0.4618
# Epoch 159/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4757 - accuracy: 0.3891
# Epoch 160/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4770 - accuracy: 0.4655
# Epoch 161/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5208 - accuracy: 0.6073
# Epoch 162/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4736 - accuracy: 0.5491
# Epoch 163/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5913 - accuracy: 0.3636
# Epoch 164/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6114 - accuracy: 0.5964
# Epoch 165/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6561 - accuracy: 0.6145
# Epoch 166/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6160 - accuracy: 0.4873
# Epoch 167/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5559 - accuracy: 0.5273
# Epoch 168/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5659 - accuracy: 0.6182
# Epoch 169/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6036 - accuracy: 0.4618
# Epoch 170/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5711 - accuracy: 0.3782
# Epoch 171/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4704 - accuracy: 0.5527
# Epoch 172/500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4657 - accuracy: 0.6073
# Epoch 173/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4697 - accuracy: 0.5018
# Epoch 174/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5055 - accuracy: 0.4618
# Epoch 175/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5793 - accuracy: 0.4727
# Epoch 176/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5295 - accuracy: 0.5455
# Epoch 177/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5828 - accuracy: 0.5673
# Epoch 178/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6342 - accuracy: 0.4727
# Epoch 179/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5822 - accuracy: 0.4836
# Epoch 180/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5380 - accuracy: 0.5927
# Epoch 181/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4775 - accuracy: 0.4327
# Epoch 182/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4921 - accuracy: 0.3891
# Epoch 183/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5770 - accuracy: 0.5782
# Epoch 184/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5181 - accuracy: 0.6436
# Epoch 185/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6899 - accuracy: 0.3273
# Epoch 186/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5935 - accuracy: 0.6327
# Epoch 187/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4472 - accuracy: 0.4655
# Epoch 188/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4602 - accuracy: 0.3527
# Epoch 189/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5522 - accuracy: 0.5891
# Epoch 190/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6031 - accuracy: 0.5127
# Epoch 191/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6910 - accuracy: 0.5236
# Epoch 192/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6008 - accuracy: 0.3636
# Epoch 193/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5216 - accuracy: 0.4909
# Epoch 194/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5136 - accuracy: 0.4364
# Epoch 195/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5121 - accuracy: 0.5418
# Epoch 196/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5566 - accuracy: 0.5564
# Epoch 197/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4728 - accuracy: 0.3891
# Epoch 198/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5155 - accuracy: 0.4764
# Epoch 199/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4603 - accuracy: 0.5345
# Epoch 200/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4429 - accuracy: 0.4800
# Epoch 201/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4215 - accuracy: 0.6400
# Epoch 202/500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5109 - accuracy: 0.4255
# Epoch 203/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5087 - accuracy: 0.4909
# Epoch 204/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4610 - accuracy: 0.5636
# Epoch 205/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4246 - accuracy: 0.4582
# Epoch 206/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4466 - accuracy: 0.5600
# Epoch 207/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5138 - accuracy: 0.3964
# Epoch 208/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5056 - accuracy: 0.3855
# Epoch 209/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5102 - accuracy: 0.6618
# Epoch 210/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5613 - accuracy: 0.4655
# Epoch 211/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5693 - accuracy: 0.5055
# Epoch 212/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4972 - accuracy: 0.4073
# Epoch 213/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5312 - accuracy: 0.5236
# Epoch 214/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5256 - accuracy: 0.4182
# Epoch 215/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6024 - accuracy: 0.6873
# Epoch 216/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6225 - accuracy: 0.4255
# Epoch 217/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6204 - accuracy: 0.2545
# Epoch 218/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6131 - accuracy: 0.6182
# Epoch 219/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5361 - accuracy: 0.4982
# Epoch 220/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5103 - accuracy: 0.3309
# Epoch 221/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4990 - accuracy: 0.5309
# Epoch 222/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5269 - accuracy: 0.6036
# Epoch 223/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4653 - accuracy: 0.4655
# Epoch 224/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5223 - accuracy: 0.4291
# Epoch 225/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4543 - accuracy: 0.4509
# Epoch 226/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4484 - accuracy: 0.5527
# Epoch 227/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5180 - accuracy: 0.5818
# Epoch 228/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4839 - accuracy: 0.5491
# Epoch 229/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5235 - accuracy: 0.3200
# Epoch 230/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5191 - accuracy: 0.5782
# Epoch 231/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4585 - accuracy: 0.5236
# Epoch 232/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4175 - accuracy: 0.4509
# Epoch 233/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4987 - accuracy: 0.4691
# Epoch 234/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4504 - accuracy: 0.6764
# Epoch 235/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4549 - accuracy: 0.4145
# Epoch 236/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4543 - accuracy: 0.5491
# Epoch 237/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4886 - accuracy: 0.5018
# Epoch 238/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4294 - accuracy: 0.5309
# Epoch 239/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4469 - accuracy: 0.5418
# Epoch 240/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5216 - accuracy: 0.3345
# Epoch 241/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5572 - accuracy: 0.6436
# Epoch 242/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5650 - accuracy: 0.3818
# Epoch 243/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5505 - accuracy: 0.4909
# Epoch 244/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5111 - accuracy: 0.5782
# Epoch 245/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5067 - accuracy: 0.4800
# Epoch 246/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5562 - accuracy: 0.4836
# Epoch 247/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6439 - accuracy: 0.4727
# Epoch 248/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5909 - accuracy: 0.5891
# Epoch 249/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.5818
# Epoch 250/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4876 - accuracy: 0.4800
# Epoch 251/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5557 - accuracy: 0.5018
# Epoch 252/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5782 - accuracy: 0.4473
# Epoch 253/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5597 - accuracy: 0.3855
# Epoch 254/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5335 - accuracy: 0.5236
# Epoch 255/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5070 - accuracy: 0.4000
# Epoch 256/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4984 - accuracy: 0.5055
# Epoch 257/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4273 - accuracy: 0.3855
# Epoch 258/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4318 - accuracy: 0.4982
# Epoch 259/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4467 - accuracy: 0.5127
# Epoch 260/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4451 - accuracy: 0.5273
# Epoch 261/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4676 - accuracy: 0.5600
# Epoch 262/500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5272 - accuracy: 0.3855
# Epoch 263/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5015 - accuracy: 0.4400
# Epoch 264/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4641 - accuracy: 0.6255
# Epoch 265/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4676 - accuracy: 0.3927
# Epoch 266/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4766 - accuracy: 0.5745
# Epoch 267/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5156 - accuracy: 0.3564
# Epoch 268/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5455 - accuracy: 0.6727
# Epoch 269/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4867 - accuracy: 0.4764
# Epoch 270/500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5264 - accuracy: 0.6509
# Epoch 271/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5535 - accuracy: 0.4618
# Epoch 272/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5712 - accuracy: 0.4509
# >1, MAE: 1.433
# Epoch 1/500
# 2022-04-27 16:14:02.854847: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-27 16:14:03.027196: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 9/9 [==============================] - 0s 8ms/step - loss: 170.3008 - accuracy: 0.5018
# Epoch 2/500
# 9/9 [==============================] - 0s 5ms/step - loss: 167.9234 - accuracy: 0.4618
# Epoch 3/500
# 9/9 [==============================] - 0s 5ms/step - loss: 165.1664 - accuracy: 0.4145
# Epoch 4/500
# 9/9 [==============================] - 0s 5ms/step - loss: 161.7142 - accuracy: 0.3964
# Epoch 5/500
# 9/9 [==============================] - 0s 5ms/step - loss: 157.1478 - accuracy: 0.4036
# Epoch 6/500
# 9/9 [==============================] - 0s 5ms/step - loss: 151.4569 - accuracy: 0.4109
# Epoch 7/500
# 9/9 [==============================] - 0s 5ms/step - loss: 144.2241 - accuracy: 0.4509
# Epoch 8/500
# 9/9 [==============================] - 0s 5ms/step - loss: 135.2445 - accuracy: 0.4727
# Epoch 9/500
# 9/9 [==============================] - 0s 5ms/step - loss: 124.5214 - accuracy: 0.5236
# Epoch 10/500
# 9/9 [==============================] - 0s 5ms/step - loss: 112.5735 - accuracy: 0.5636
# Epoch 11/500
# 9/9 [==============================] - 0s 5ms/step - loss: 101.0906 - accuracy: 0.6218
# Epoch 12/500
# 9/9 [==============================] - 0s 5ms/step - loss: 88.6957 - accuracy: 0.7055
# Epoch 13/500
# 9/9 [==============================] - 0s 5ms/step - loss: 75.5012 - accuracy: 0.7527
# Epoch 14/500
# 9/9 [==============================] - 0s 5ms/step - loss: 63.0819 - accuracy: 0.8400
# Epoch 15/500
# 9/9 [==============================] - 0s 5ms/step - loss: 51.9236 - accuracy: 0.9600
# Epoch 16/500
# 9/9 [==============================] - 0s 5ms/step - loss: 42.8209 - accuracy: 0.9818
# Epoch 17/500
# 9/9 [==============================] - 0s 5ms/step - loss: 36.0132 - accuracy: 0.9418
# Epoch 18/500
# 9/9 [==============================] - 0s 5ms/step - loss: 30.2751 - accuracy: 0.8873
# Epoch 19/500
# 9/9 [==============================] - 0s 5ms/step - loss: 25.5901 - accuracy: 0.8218
# Epoch 20/500
# 9/9 [==============================] - 0s 5ms/step - loss: 21.1447 - accuracy: 0.6982
# Epoch 21/500
# 9/9 [==============================] - 0s 5ms/step - loss: 17.9202 - accuracy: 0.5745
# Epoch 22/500
# 9/9 [==============================] - 0s 5ms/step - loss: 15.4564 - accuracy: 0.5527
# Epoch 23/500
# 9/9 [==============================] - 0s 5ms/step - loss: 13.5113 - accuracy: 0.5745
# Epoch 24/500
# 9/9 [==============================] - 0s 5ms/step - loss: 11.9419 - accuracy: 0.5200
# Epoch 25/500
# 9/9 [==============================] - 0s 5ms/step - loss: 10.7838 - accuracy: 0.4982
# Epoch 26/500
# 9/9 [==============================] - 0s 5ms/step - loss: 9.7428 - accuracy: 0.4436
# Epoch 27/500
# 9/9 [==============================] - 0s 5ms/step - loss: 8.8808 - accuracy: 0.3564
# Epoch 28/500
# 9/9 [==============================] - 0s 5ms/step - loss: 8.2404 - accuracy: 0.4145
# Epoch 29/500
# 9/9 [==============================] - 0s 5ms/step - loss: 7.5729 - accuracy: 0.4036
# Epoch 30/500
# 9/9 [==============================] - 0s 6ms/step - loss: 7.0231 - accuracy: 0.3455
# Epoch 31/500
# 9/9 [==============================] - 0s 6ms/step - loss: 6.4528 - accuracy: 0.3745
# Epoch 32/500
# 9/9 [==============================] - 0s 6ms/step - loss: 5.8770 - accuracy: 0.4182
# Epoch 33/500
# 9/9 [==============================] - 0s 5ms/step - loss: 5.4138 - accuracy: 0.3673
# Epoch 34/500
# 9/9 [==============================] - 0s 6ms/step - loss: 4.9333 - accuracy: 0.4255
# Epoch 35/500
# 9/9 [==============================] - 0s 7ms/step - loss: 4.4661 - accuracy: 0.5273
# Epoch 36/500
# 9/9 [==============================] - 0s 5ms/step - loss: 3.9995 - accuracy: 0.3309
# Epoch 37/500
# 9/9 [==============================] - 0s 4ms/step - loss: 3.7569 - accuracy: 0.3236
# Epoch 38/500
# 9/9 [==============================] - 0s 5ms/step - loss: 3.3956 - accuracy: 0.5236
# Epoch 39/500
# 9/9 [==============================] - 0s 7ms/step - loss: 3.0274 - accuracy: 0.3018
# Epoch 40/500
# 9/9 [==============================] - 0s 6ms/step - loss: 2.7882 - accuracy: 0.5418
# Epoch 41/500
# 9/9 [==============================] - 0s 6ms/step - loss: 2.5370 - accuracy: 0.5055
# Epoch 42/500
# 9/9 [==============================] - 0s 8ms/step - loss: 2.4228 - accuracy: 0.6073
# Epoch 43/500
# 9/9 [==============================] - 0s 6ms/step - loss: 2.3018 - accuracy: 0.4836
# Epoch 44/500
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1532 - accuracy: 0.4509
# Epoch 45/500
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1453 - accuracy: 0.4400
# Epoch 46/500
# 9/9 [==============================] - 0s 4ms/step - loss: 1.9853 - accuracy: 0.4582
# Epoch 47/500
# 9/9 [==============================] - 0s 4ms/step - loss: 1.7334 - accuracy: 0.4982
# Epoch 48/500
# 9/9 [==============================] - 0s 4ms/step - loss: 1.6341 - accuracy: 0.5055
# Epoch 49/500
# 9/9 [==============================] - 0s 9ms/step - loss: 1.5551 - accuracy: 0.4436
# Epoch 50/500
# 9/9 [==============================] - 0s 7ms/step - loss: 1.4689 - accuracy: 0.5709
# Epoch 51/500
# 9/9 [==============================] - 0s 6ms/step - loss: 1.3651 - accuracy: 0.4982
# Epoch 52/500
# 9/9 [==============================] - 0s 6ms/step - loss: 1.3289 - accuracy: 0.5236
# Epoch 53/500
# 9/9 [==============================] - 0s 6ms/step - loss: 1.2567 - accuracy: 0.5673
# Epoch 54/500
# 9/9 [==============================] - 0s 6ms/step - loss: 1.2489 - accuracy: 0.5855
# Epoch 55/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.2338 - accuracy: 0.4982
# Epoch 56/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.1880 - accuracy: 0.4982
# Epoch 57/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.1567 - accuracy: 0.6291
# Epoch 58/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.2186 - accuracy: 0.6073
# Epoch 59/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.1013 - accuracy: 0.5200
# Epoch 60/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0731 - accuracy: 0.4509
# Epoch 61/500
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0366 - accuracy: 0.4800
# Epoch 62/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0027 - accuracy: 0.6218
# Epoch 63/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0025 - accuracy: 0.4873
# Epoch 64/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9831 - accuracy: 0.5273
# Epoch 65/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0001 - accuracy: 0.5564
# Epoch 66/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9967 - accuracy: 0.5127
# Epoch 67/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0063 - accuracy: 0.4655
# Epoch 68/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9970 - accuracy: 0.5636
# Epoch 69/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9055 - accuracy: 0.5382
# Epoch 70/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9271 - accuracy: 0.5709
# Epoch 71/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9242 - accuracy: 0.5055
# Epoch 72/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9345 - accuracy: 0.5855
# Epoch 73/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9022 - accuracy: 0.5236
# Epoch 74/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8725 - accuracy: 0.5418
# Epoch 75/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8072 - accuracy: 0.3455
# Epoch 76/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8429 - accuracy: 0.6145
# Epoch 77/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8080 - accuracy: 0.4473
# Epoch 78/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8144 - accuracy: 0.5564
# Epoch 79/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8131 - accuracy: 0.5636
# Epoch 80/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8246 - accuracy: 0.4691
# Epoch 81/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8281 - accuracy: 0.4836
# Epoch 82/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7369 - accuracy: 0.5891
# Epoch 83/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7526 - accuracy: 0.5273
# Epoch 84/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8378 - accuracy: 0.5600
# Epoch 85/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8978 - accuracy: 0.4291
# Epoch 86/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8609 - accuracy: 0.5527
# Epoch 87/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7571 - accuracy: 0.5673
# Epoch 88/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7187 - accuracy: 0.4582
# Epoch 89/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6713 - accuracy: 0.6109
# Epoch 90/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6881 - accuracy: 0.4545
# Epoch 91/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7294 - accuracy: 0.4400
# Epoch 92/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7117 - accuracy: 0.5018
# Epoch 93/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6872 - accuracy: 0.4727
# Epoch 94/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6087 - accuracy: 0.4982
# Epoch 95/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6057 - accuracy: 0.6000
# Epoch 96/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6688 - accuracy: 0.5673
# Epoch 97/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7530 - accuracy: 0.3891
# Epoch 98/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6741 - accuracy: 0.5127
# Epoch 99/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6866 - accuracy: 0.4982
# Epoch 100/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7127 - accuracy: 0.5673
# Epoch 101/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7072 - accuracy: 0.3927
# Epoch 102/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6592 - accuracy: 0.6218
# Epoch 103/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6841 - accuracy: 0.4655
# Epoch 104/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7221 - accuracy: 0.4436
# Epoch 105/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7391 - accuracy: 0.5382
# Epoch 106/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6166 - accuracy: 0.3891
# Epoch 107/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6014 - accuracy: 0.5273
# Epoch 108/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6047 - accuracy: 0.5418
# Epoch 109/500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6445 - accuracy: 0.6655
# Epoch 110/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6310 - accuracy: 0.3927
# Epoch 111/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6480 - accuracy: 0.5382
# Epoch 112/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6626 - accuracy: 0.4182
# Epoch 113/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6306 - accuracy: 0.5673
# Epoch 114/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6271 - accuracy: 0.5891
# Epoch 115/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5757 - accuracy: 0.3855
# Epoch 116/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6520 - accuracy: 0.5564
# Epoch 117/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5696 - accuracy: 0.6364
# Epoch 118/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5387 - accuracy: 0.4582
# Epoch 119/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5349 - accuracy: 0.5527
# Epoch 120/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5462 - accuracy: 0.4109
# Epoch 121/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5826 - accuracy: 0.5782
# Epoch 122/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6361 - accuracy: 0.4255
# Epoch 123/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6655 - accuracy: 0.5200
# Epoch 124/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5651 - accuracy: 0.4691
# Epoch 125/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6050 - accuracy: 0.5745
# Epoch 126/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5716 - accuracy: 0.4545
# Epoch 127/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5474 - accuracy: 0.5673
# Epoch 128/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5595 - accuracy: 0.4836
# Epoch 129/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5944 - accuracy: 0.5236
# Epoch 130/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6382 - accuracy: 0.5745
# Epoch 131/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5685 - accuracy: 0.5236
# Epoch 132/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5617 - accuracy: 0.3891
# Epoch 133/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5788 - accuracy: 0.3927
# Epoch 134/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5519 - accuracy: 0.5491
# Epoch 135/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5425 - accuracy: 0.4836
# Epoch 136/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6141 - accuracy: 0.4727
# Epoch 137/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5698 - accuracy: 0.5382
# Epoch 138/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5800 - accuracy: 0.6182
# Epoch 139/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5761 - accuracy: 0.5091
# Epoch 140/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5877 - accuracy: 0.3273
# Epoch 141/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5434 - accuracy: 0.4836
# Epoch 142/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6036 - accuracy: 0.6182
# Epoch 143/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5463 - accuracy: 0.5636
# Epoch 144/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5716 - accuracy: 0.3818
# Epoch 145/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6051 - accuracy: 0.4836
# Epoch 146/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5968 - accuracy: 0.5127
# Epoch 147/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5409 - accuracy: 0.5782
# Epoch 148/500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.6218 - accuracy: 0.5636
# Epoch 149/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6019 - accuracy: 0.4182
# Epoch 150/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5854 - accuracy: 0.4873
# Epoch 151/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5386 - accuracy: 0.4800
# Epoch 152/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5487 - accuracy: 0.6145
# Epoch 153/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5099 - accuracy: 0.5309
# Epoch 154/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5608 - accuracy: 0.4291
# Epoch 155/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5044 - accuracy: 0.3782
# Epoch 156/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4615 - accuracy: 0.4982
# Epoch 157/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4505 - accuracy: 0.5636
# Epoch 158/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4511 - accuracy: 0.5527
# Epoch 159/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4911 - accuracy: 0.5018
# Epoch 160/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4807 - accuracy: 0.5018
# Epoch 161/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5335 - accuracy: 0.5964
# Epoch 162/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5758 - accuracy: 0.5600
# Epoch 163/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5536 - accuracy: 0.4545
# Epoch 164/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6007 - accuracy: 0.5273
# Epoch 165/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5970 - accuracy: 0.4327
# Epoch 166/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6425 - accuracy: 0.5927
# Epoch 167/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6260 - accuracy: 0.4327
# Epoch 168/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5624 - accuracy: 0.5455
# Epoch 169/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5608 - accuracy: 0.4800
# Epoch 170/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5652 - accuracy: 0.4073
# Epoch 171/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5549 - accuracy: 0.6073
# Epoch 172/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5069 - accuracy: 0.4800
# Epoch 173/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4918 - accuracy: 0.5164
# Epoch 174/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5238 - accuracy: 0.4655
# Epoch 175/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6005 - accuracy: 0.4727
# Epoch 176/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6146 - accuracy: 0.4836
# Epoch 177/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6040 - accuracy: 0.7091
# Epoch 178/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6293 - accuracy: 0.3855
# Epoch 179/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6634 - accuracy: 0.5600
# Epoch 180/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5489 - accuracy: 0.5818
# Epoch 181/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5669 - accuracy: 0.4727
# Epoch 182/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5728 - accuracy: 0.5055
# Epoch 183/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5510 - accuracy: 0.5600
# Epoch 184/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5186 - accuracy: 0.4073
# Epoch 185/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5257 - accuracy: 0.5564
# Epoch 186/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4665 - accuracy: 0.5055
# Epoch 187/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4612 - accuracy: 0.4509
# Epoch 188/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4813 - accuracy: 0.4618
# Epoch 189/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4600 - accuracy: 0.5600
# Epoch 190/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4670 - accuracy: 0.4582
# Epoch 191/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4680 - accuracy: 0.4691
# Epoch 192/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4944 - accuracy: 0.5164
# Epoch 193/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6126 - accuracy: 0.4982
# Epoch 194/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5286 - accuracy: 0.3309
# Epoch 195/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4787 - accuracy: 0.6218
# Epoch 196/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5183 - accuracy: 0.5745
# Epoch 197/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4921 - accuracy: 0.5127
# >2, MAE: 1.454
# Epoch 1/500
# 2022-04-27 16:14:12.446263: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-27 16:14:12.604682: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 9/9 [==============================] - 0s 11ms/step - loss: 170.2890 - accuracy: 0.5345
# Epoch 2/500
# 9/9 [==============================] - 0s 5ms/step - loss: 167.8754 - accuracy: 0.4764
# Epoch 3/500
# 9/9 [==============================] - 0s 5ms/step - loss: 165.1631 - accuracy: 0.4436
# Epoch 4/500
# 9/9 [==============================] - 0s 5ms/step - loss: 161.7355 - accuracy: 0.4400
# Epoch 5/500
# 9/9 [==============================] - 0s 5ms/step - loss: 157.2217 - accuracy: 0.4727
# Epoch 6/500
# 9/9 [==============================] - 0s 5ms/step - loss: 151.4972 - accuracy: 0.4873
# Epoch 7/500
# 9/9 [==============================] - 0s 5ms/step - loss: 144.2468 - accuracy: 0.5127
# Epoch 8/500
# 9/9 [==============================] - 0s 5ms/step - loss: 135.3411 - accuracy: 0.5273
# Epoch 9/500
# 9/9 [==============================] - 0s 5ms/step - loss: 124.5466 - accuracy: 0.5382
# ...
# Epoch 7/500
# 9/9 [==============================] - 0s 5ms/step - loss: 144.2216 - accuracy: 0.5200
# Epoch 8/500
# 9/9 [==============================] - 0s 5ms/step - loss: 135.2207 - accuracy: 0.5309
# Epoch 9/500
# 9/9 [==============================] - 0s 5ms/step - loss: 124.5394 - accuracy: 0.5491
# Epoch 10/500
# 9/9 [==============================] - 0s 5ms/step - loss: 112.7279 - accuracy: 0.5745
# Epoch 11/500
# 9/9 [==============================] - 0s 5ms/step - loss: 101.3837 - accuracy: 0.6327
# Epoch 12/500
# 9/9 [==============================] - 0s 5ms/step - loss: 88.9547 - accuracy: 0.7018
# Epoch 13/500
# 9/9 [==============================] - 0s 5ms/step - loss: 75.9056 - accuracy: 0.7345
# Epoch 14/500
# 9/9 [==============================] - 0s 5ms/step - loss: 63.3412 - accuracy: 0.8109
# Epoch 15/500
# 9/9 [==============================] - 0s 5ms/step - loss: 51.9512 - accuracy: 0.9527
# Epoch 16/500
# 9/9 [==============================] - 0s 5ms/step - loss: 42.2713 - accuracy: 0.9673
# Epoch 17/500
# 9/9 [==============================] - 0s 5ms/step - loss: 35.1596 - accuracy: 0.9527
# Epoch 18/500
# 9/9 [==============================] - 0s 5ms/step - loss: 29.4909 - accuracy: 0.8909
# Epoch 19/500
# 9/9 [==============================] - 0s 5ms/step - loss: 24.5303 - accuracy: 0.7964
# Epoch 20/500
# 9/9 [==============================] - 0s 5ms/step - loss: 20.4005 - accuracy: 0.6545
# Epoch 21/500
# 9/9 [==============================] - 0s 5ms/step - loss: 17.3670 - accuracy: 0.4473
# Epoch 22/500
# 9/9 [==============================] - 0s 5ms/step - loss: 15.1886 - accuracy: 0.3345
# Epoch 23/500
# 9/9 [==============================] - 0s 5ms/step - loss: 13.4819 - accuracy: 0.3782
# Epoch 24/500
# 9/9 [==============================] - 0s 5ms/step - loss: 11.9862 - accuracy: 0.5018
# Epoch 25/500
# 9/9 [==============================] - 0s 5ms/step - loss: 10.8641 - accuracy: 0.5455
# Epoch 26/500
# 9/9 [==============================] - 0s 5ms/step - loss: 9.7948 - accuracy: 0.4764
# Epoch 27/500
# 9/9 [==============================] - 0s 5ms/step - loss: 8.9634 - accuracy: 0.4218
# Epoch 28/500
# 9/9 [==============================] - 0s 5ms/step - loss: 8.2243 - accuracy: 0.4436
# Epoch 29/500
# 9/9 [==============================] - 0s 5ms/step - loss: 7.6069 - accuracy: 0.5018
# Epoch 30/500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.9406 - accuracy: 0.4655
# Epoch 31/500
# 9/9 [==============================] - 0s 5ms/step - loss: 6.4390 - accuracy: 0.4109
# Epoch 32/500
# 9/9 [==============================] - 0s 5ms/step - loss: 5.9701 - accuracy: 0.4618
# Epoch 33/500
# 9/9 [==============================] - 0s 5ms/step - loss: 5.4152 - accuracy: 0.4509
# Epoch 34/500
# 9/9 [==============================] - 0s 5ms/step - loss: 4.9098 - accuracy: 0.4691
# Epoch 35/500
# 9/9 [==============================] - 0s 5ms/step - loss: 4.4395 - accuracy: 0.4655
# Epoch 36/500
# 9/9 [==============================] - 0s 5ms/step - loss: 3.9711 - accuracy: 0.5455
# Epoch 37/500
# 9/9 [==============================] - 0s 5ms/step - loss: 3.6037 - accuracy: 0.4691
# Epoch 38/500
# 9/9 [==============================] - 0s 5ms/step - loss: 3.2339 - accuracy: 0.3818
# Epoch 39/500
# 9/9 [==============================] - 0s 5ms/step - loss: 2.8971 - accuracy: 0.4364
# Epoch 40/500
# 9/9 [==============================] - 0s 5ms/step - loss: 2.6360 - accuracy: 0.4582
# Epoch 41/500
# 9/9 [==============================] - 0s 5ms/step - loss: 2.4328 - accuracy: 0.4582
# Epoch 42/500
# 9/9 [==============================] - 0s 5ms/step - loss: 2.2791 - accuracy: 0.4873
# Epoch 43/500
# 9/9 [==============================] - 0s 5ms/step - loss: 2.1183 - accuracy: 0.5164
# Epoch 44/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.9290 - accuracy: 0.4582
# Epoch 45/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.8614 - accuracy: 0.3855
# Epoch 46/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.7181 - accuracy: 0.5091
# Epoch 47/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.5983 - accuracy: 0.4982
# Epoch 48/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.4895 - accuracy: 0.5527
# Epoch 49/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.4709 - accuracy: 0.4509
# Epoch 50/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.4609 - accuracy: 0.4509
# Epoch 51/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.4146 - accuracy: 0.6764
# Epoch 52/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.2791 - accuracy: 0.3818
# Epoch 53/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.2464 - accuracy: 0.5745
# Epoch 54/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.2926 - accuracy: 0.4400
# Epoch 55/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.2917 - accuracy: 0.4618
# Epoch 56/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.2589 - accuracy: 0.5382
# Epoch 57/500
# 9/9 [==============================] - 0s 4ms/step - loss: 1.2634 - accuracy: 0.4073
# Epoch 58/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.4409 - accuracy: 0.6618
# Epoch 59/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.2885 - accuracy: 0.3855
# Epoch 60/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.1642 - accuracy: 0.4327
# Epoch 61/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0970 - accuracy: 0.5491
# Epoch 62/500
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0694 - accuracy: 0.5236
# Epoch 63/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9996 - accuracy: 0.5636
# Epoch 64/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9815 - accuracy: 0.4691
# Epoch 65/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9927 - accuracy: 0.4764
# Epoch 66/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9766 - accuracy: 0.5127
# Epoch 67/500
# 9/9 [==============================] - 0s 5ms/step - loss: 1.0439 - accuracy: 0.5309
# Epoch 68/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9281 - accuracy: 0.5455
# Epoch 69/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8615 - accuracy: 0.4400
# Epoch 70/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8568 - accuracy: 0.4618
# Epoch 71/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8609 - accuracy: 0.4873
# Epoch 72/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8454 - accuracy: 0.5273
# Epoch 73/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8054 - accuracy: 0.4836
# Epoch 74/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7933 - accuracy: 0.5091
# Epoch 75/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8375 - accuracy: 0.5564
# Epoch 76/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7831 - accuracy: 0.4436
# Epoch 77/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7732 - accuracy: 0.5273
# Epoch 78/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7810 - accuracy: 0.5345
# Epoch 79/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8230 - accuracy: 0.4618
# Epoch 80/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7868 - accuracy: 0.5273
# Epoch 81/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8170 - accuracy: 0.6073
# Epoch 82/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7577 - accuracy: 0.4764
# Epoch 83/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7252 - accuracy: 0.5564
# Epoch 84/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7999 - accuracy: 0.4873
# Epoch 85/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7935 - accuracy: 0.4909
# Epoch 86/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8742 - accuracy: 0.4545
# Epoch 87/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8296 - accuracy: 0.5673
# Epoch 88/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7962 - accuracy: 0.5527
# Epoch 89/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7867 - accuracy: 0.4618
# Epoch 90/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7836 - accuracy: 0.4800
# Epoch 91/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8027 - accuracy: 0.5164
# Epoch 92/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7508 - accuracy: 0.4945
# Epoch 93/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6288 - accuracy: 0.5382
# Epoch 94/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6435 - accuracy: 0.4473
# Epoch 95/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6718 - accuracy: 0.4327
# Epoch 96/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6382 - accuracy: 0.4327
# Epoch 97/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6661 - accuracy: 0.5745
# Epoch 98/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7171 - accuracy: 0.4145
# Epoch 99/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6499 - accuracy: 0.5091
# Epoch 100/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7023 - accuracy: 0.4473
# Epoch 101/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8066 - accuracy: 0.5564
# Epoch 102/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7737 - accuracy: 0.6545
# Epoch 103/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6962 - accuracy: 0.4873
# Epoch 104/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7570 - accuracy: 0.6073
# Epoch 105/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8293 - accuracy: 0.4400
# Epoch 106/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8610 - accuracy: 0.6109
# Epoch 107/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8056 - accuracy: 0.5127
# Epoch 108/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7435 - accuracy: 0.5200
# Epoch 109/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7103 - accuracy: 0.4873
# Epoch 110/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7067 - accuracy: 0.5309
# Epoch 111/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6726 - accuracy: 0.4182
# Epoch 112/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6071 - accuracy: 0.4109
# Epoch 113/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6543 - accuracy: 0.5418
# Epoch 114/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6709 - accuracy: 0.6218
# Epoch 115/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7292 - accuracy: 0.3855
# Epoch 116/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6407 - accuracy: 0.5273
# Epoch 117/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6924 - accuracy: 0.5527
# Epoch 118/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6754 - accuracy: 0.5600
# Epoch 119/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6503 - accuracy: 0.4400
# Epoch 120/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6407 - accuracy: 0.5164
# Epoch 121/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5826 - accuracy: 0.4691
# Epoch 122/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6273 - accuracy: 0.5891
# Epoch 123/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5894 - accuracy: 0.5127
# Epoch 124/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5600 - accuracy: 0.5200
# Epoch 125/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5394 - accuracy: 0.5055
# Epoch 126/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4946 - accuracy: 0.4691
# Epoch 127/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5365 - accuracy: 0.4691
# Epoch 128/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5609 - accuracy: 0.5309
# Epoch 129/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5536 - accuracy: 0.4836
# Epoch 130/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5738 - accuracy: 0.3891
# Epoch 131/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6155 - accuracy: 0.4800
# Epoch 132/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5653 - accuracy: 0.5309
# Epoch 133/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6622 - accuracy: 0.5673
# Epoch 134/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6264 - accuracy: 0.2945
# Epoch 135/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6284 - accuracy: 0.5200
# Epoch 136/500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5312 - accuracy: 0.5200
# Epoch 137/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5528 - accuracy: 0.4655
# Epoch 138/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5343 - accuracy: 0.5927
# Epoch 139/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5534 - accuracy: 0.4400
# Epoch 140/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5070 - accuracy: 0.5091
# Epoch 141/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5975 - accuracy: 0.5455
# Epoch 142/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6024 - accuracy: 0.4509
# Epoch 143/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5829 - accuracy: 0.5091
# Epoch 144/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5647 - accuracy: 0.5673
# Epoch 145/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6042 - accuracy: 0.4327
# Epoch 146/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7062 - accuracy: 0.6000
# Epoch 147/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7217 - accuracy: 0.5309
# Epoch 148/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6980 - accuracy: 0.4836
# Epoch 149/500
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6306 - accuracy: 0.5636
# Epoch 150/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6860 - accuracy: 0.5455
# Epoch 151/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5822 - accuracy: 0.4873
# Epoch 152/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5818 - accuracy: 0.5236
# Epoch 153/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4983 - accuracy: 0.4327
# Epoch 154/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5773 - accuracy: 0.4691
# Epoch 155/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5346 - accuracy: 0.5418
# Epoch 156/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5254 - accuracy: 0.5055
# Epoch 157/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5249 - accuracy: 0.5564
# Epoch 158/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5676 - accuracy: 0.4655
# Epoch 159/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5426 - accuracy: 0.5236
# Epoch 160/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5320 - accuracy: 0.5200
# Epoch 161/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5716 - accuracy: 0.4909
# Epoch 162/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5351 - accuracy: 0.3673
# Epoch 163/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5862 - accuracy: 0.4545
# Epoch 164/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6598 - accuracy: 0.5636
# Epoch 165/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5494 - accuracy: 0.5382
# Epoch 166/500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6027 - accuracy: 0.4545
# >5, MAE: 1.304
# 2022-04-27 16:14:45.015445: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
if dist1 != np.inf and dist2 != 0:
            percentError = (abs(dist1 - dist2) / dist2) * 100
            percentErrors.append(percentError)
            numTrials += 1

            percentError2 = (abs(dist3 - dist2) / dist2) * 100
            percentErrors2.append(percentError2)

            subTimes1.append(subElaspedTime1)
            times1.append(elapsedTime1)
            times2.append(elapsedTime2)
            times3.append(elapsedTime3)

            dtwvis.plot_warpingpaths(x1, x2, dtw_matrix, best_path1)
            dtwvis.plot_warpingpaths(x1, x2, dtw_matrix2, best_path2)
            dtwvis.plot_warpingpaths(x1, x2, dtw_matrix3, best_path3)

   
p1q1, p1q2, p1q3 = np.percentile(percentErrors,[25,50,75])

p2q1, p2q2, p2q3 = np.percentile(percentErrors2,[25,50,75])

t1q1, t1q2, t1q3 = np.percentile(times1,[25,50,75])
t2q1, t2q2, t2q3 = np.percentile(times2,[25,50,75])
t3q1, t3q2, t3q3 = np.percentile(times3,[25,50,75])
s1q1, s1q2, s1q3 = np.percentile(subTimes1,[25,50,75])

print("Num of Trials:", len(percentErrors))

print("ml:")
print("percent error:", "     q1:", p1q1, "     q2:", p1q2, "     q3:", p1q3)
print("time:", "     q1:", t1q1, "     q2:", t1q2, "     q3:", t1q3,"     ml subtime:", "     q1:", s1q1,"     q2:", s1q2,"     q3:", s1q3)
print("dtwfast:")
print("percent error:", "     q1:", p2q1, "     q2:", p2q2, "     q3:", p2q3)
print("time:", "     q1:", t3q1, "     q2:", t3q2, "     q3:", t3q3)
print("Full DTW:")
print("time:", "     q1:", t2q1, "     q2:", t2q2, "     q3:", t2q3)

print(percentErrors2)
print(percentErrors)
print(times2)
print(times3)
print(subTimes1)
print(times1)
